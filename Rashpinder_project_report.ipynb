# %%
import pandas as pd

# %% [markdown]
# ## 1.	Import the dataset: Load the data into your analysis environment.

# %%
retail=pd.read_csv("SampleSuperstore.csv")

# %% [markdown]
# ## 2.	Display records: Show the first 5 and last 5 records of the dataset.

# %%
retail
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
retail.shape
# Out:
# (9994, 13)

# %% [markdown]
# ## 3.	Identify data types: Check and note the data types for each variable.

# %%
retail.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [raw]
# Interpretation:
#
# Postal Code need not to be int64, it should be object.
# All the other variables have significant data types.

# %%
retail['Postal Code']=retail['Postal Code'].astype('object')

# %%
retail.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code      object
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ## 4.	Missing entries: Determine the number of missing entries per variable.

# %%
retail.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [raw]
# All the columns have none missing values.

# %% [markdown]
# ## 5.	Duplicate records: Identify and count any duplicate records.

# %%
retail.duplicated().sum()
# Out:
# 17

# %%
retail[retail.duplicated()]
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# 7735  Standard Class    Corporate  United States        Seattle    Washington
# ...

# %% [raw]
# The above record is not duplicated as the values of each column in any of the above rows is not exactly same, so we do not drop any of the columns.

# %% [markdown]
# ## 6.	Univariate analysis: Conduct this analysis on all variables, creating appropriate visualizations.

# %% [raw]
# Univariate analysis is the analysis of a single variable. It helps to understand the distribution and spread of the data for each feature/column in a dataset.
# In univariate analysis, we typically focus on the following:
#
# Numerical variables:
# For continuous or discrete data, we look at:
# 1. Measures of central tendency (mean, median, mode)
# 2. Measures of dispersion (range, variance, standard deviation, interquartile range)
# 3. Visualizations: Histograms, box plots, density plots
#
# Categorical variables:
# For categorical data, we examine:
# 1. Frequency distribution (counts of each category)
# 2. Visualizations: Bar plots, pie charts

# %% [markdown]
# ## Visualisation:

# %%
# libraries for visualisation

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Univariate Analysis for Categorical Variables
categorical_columns = ['Ship Mode', 'Segment', 'Region', 'Category', 'Sub-Category']
# We do not include Country, City, State and Postal Code because of the large variety of values in the fields, it is hard to visualise properly.

# Create bar plots for categorical variables
plt.figure(figsize=(12, 10))
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(3, 3, i)
    sns.countplot(data=retail, x=col, color='green')
    plt.title(f"Count of {col}")
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Univariate Analysis for Numerical Variables
numerical_columns = ['Sales', 'Quantity', 'Discount', 'Profit']

# Create histograms and box plots for numerical variables
plt.figure(figsize=(14, 10))

for i, col in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)
    sns.histplot(retail[col], kde=True, bins=10, color='green')
    plt.title(f"Distribution of {col}")

plt.tight_layout()
plt.show()

# Box plots for numerical variables
plt.figure(figsize=(14, 10))

for i, col in enumerate(numerical_columns, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(data=retail, x=col, color='green')
    plt.title(f"Box plot of {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Statistical analysis:

# %% [raw]
# For numerical Variables:

# %%
retail.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [raw]
# For Categorical Variables:

# %%
retail.describe(include='object')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
#
#         Postal Code Region         Category Sub-Category
# count          9994   9994             9994         9994
# unique          631      4                3           17
# top           10035   West  Office Supplies      Binders
# freq            263   3203             6026         1523

# %%
for cols in retail.columns:
    if retail[cols].dtype=='object':
        levels_cat=retail[cols].value_counts()
        print(f'Level of {cols} is following:{levels_cat}')
# Out:
# Level of Ship Mode is following:Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64
# Level of Segment is following:Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64
# Level of Country is following:Country
# United States    9994
# Name: count, dtype: int64
# Level of City is following:City
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: count, Length: 531, dtype: int64
# Level of State is following:State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# ...

# %% [markdown]
# ## 7.	Outlier detection: Use the Tukey method to identify outliers.

# %%
def tukey_outliers(df, column):
    # Step 1: Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    
    # Step 2: Calculate IQR
    IQR = Q3 - Q1
    
    # Step 3: Define the lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Step 4: Identify outliers
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    
    return outliers, lower_bound, upper_bound

# %%
# Detect outliers in the 'Sales' column
outliers, lower, upper = tukey_outliers(retail, 'Sales')

# Display the outliers
print("Outliers detected:")
print(outliers.T)
print(f"Lower bound: {lower}")
print(f"Upper bound: {upper}")
# Out:
# Outliers detected:
#                        1                3               7               10    \
# Ship Mode      Second Class   Standard Class  Standard Class  Standard Class
# Segment            Consumer         Consumer        Consumer        Consumer
# Country       United States    United States   United States   United States
# City              Henderson  Fort Lauderdale     Los Angeles     Los Angeles
# State              Kentucky          Florida      California      California
# Postal Code           42420            33311           90032           90032
# Region                South            South            West            West
# Category          Furniture        Furniture      Technology       Furniture
# Sub-Category         Chairs           Tables          Phones          Tables
# Sales                731.94         957.5775         907.152        1706.184
# Quantity                  3                5               6               9
# ...

# %%
# Detect outliers in the 'Quantity' column
outliers, lower, upper = tukey_outliers(retail, 'Quantity')

# Display the outliers
print("Total Outliers:" ,outliers.count())
print("Outliers detected:")
print(outliers.T)
print(f"Lower bound: {lower}")
print(f"Upper bound: {upper}")
# Out:
# Total Outliers: Ship Mode       170
# Segment         170
# Country         170
# City            170
# State           170
# Postal Code     170
# Region          170
# Category        170
# Sub-Category    170
# Sales           170
# Quantity        170
# Discount        170
# Profit          170
# dtype: int64
# Outliers detected:
#                          113             139             147             251   \
# Ship Mode        Second Class  Standard Class  Standard Class  Standard Class
# Segment              Consumer        Consumer       Corporate        Consumer
# Country         United States   United States   United States   United States
# City                 Columbus       Roseville        Franklin       San Diego
# State                    Ohio      California       Wisconsin      California
# Postal Code             43229           95661           53132           92037
# Region                   East            West         Central            West
# ...

# %%
# Detect outliers in the 'Discount' column
outliers, lower, upper = tukey_outliers(retail, 'Discount')

# Display the outliers
print("Total Outliers:" ,outliers.count())
print("Outliers detected:")
print(outliers.T)
print(f"Lower bound: {lower}")
print(f"Upper bound: {upper}")
# Out:
# Total Outliers: Ship Mode       856
# Segment         856
# Country         856
# City            856
# State           856
# Postal Code     856
# Region          856
# Category        856
# Sub-Category    856
# Sales           856
# Quantity        856
# Discount        856
# Profit          856
# dtype: int64
# Outliers detected:
#                          14               15               28    \
# Ship Mode      Standard Class   Standard Class   Standard Class
# Segment           Home Office      Home Office         Consumer
# Country         United States    United States    United States
# City               Fort Worth       Fort Worth     Philadelphia
# State                   Texas            Texas     Pennsylvania
# Postal Code             76106            76106            19140
# Region                Central          Central             East
# Category      Office Supplies  Office Supplies  Office Supplies
# ...

# %%
# Detect outliers in the 'Profit' column
outliers, lower, upper = tukey_outliers(retail, 'Profit')

# Display the outliers
print("Total Outliers:" ,outliers.count())
print("Outliers detected:")
print(outliers.T)
print(f"Lower bound: {lower}")
print(f"Upper bound: {upper}")
# Out:
# Total Outliers: Ship Mode       1881
# Segment         1881
# Country         1881
# City            1881
# State           1881
# Postal Code     1881
# Region          1881
# Category        1881
# Sub-Category    1881
# Sales           1881
# Quantity        1881
# Discount        1881
# Profit          1881
# dtype: int64
# Outliers detected:
#                        1                3               7               10    \
# Ship Mode      Second Class   Standard Class  Standard Class  Standard Class
# Segment            Consumer         Consumer        Consumer        Consumer
# Country       United States    United States   United States   United States
# City              Henderson  Fort Lauderdale     Los Angeles     Los Angeles
# State              Kentucky          Florida      California      California
# Postal Code           42420            33311           90032           90032
# Region                South            South            West            West
# ...

# %% [raw]
# Upon Detection, Sales and Profit have lots of outliers whereas Discount have slightly less and Quantity have least amount of outliers.
# As we have few methods to deal with outliers, I will remove the rows in order to clean the data as we have lot of data in our dataset, we will have significant amount of rows left to perform our analysis even after removing rows with outliers.

# %%
# Remove rows with outliers based on Tukey's method
def remove_outliers(df, column, lower_bound, upper_bound):
    # Filter data to keep only rows within the lower and upper bounds
    df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_filtered

# %%
lower_bound= -271.71000000000004
upper_bound= 498.93

# Apply this function to 'Sales' column
retail_filtered = remove_outliers(retail, 'Sales', lower_bound, upper_bound)

# Check the shape of the dataset after removing outliers
print(f"Original dataset shape: {retail.shape}")
print(f"Filtered dataset shape: {retail_filtered.shape}")
# Out:
# Original dataset shape: (9994, 13)
# Filtered dataset shape: (8827, 13)

# %%
lower_bound= -2.5
upper_bound= 9.5

# Apply this function to 'Quantity' column
retail_filtered1 = remove_outliers(retail_filtered, 'Quantity', lower_bound, upper_bound)

# Check the shape of the dataset after removing outliers
print(f"Original dataset shape: {retail_filtered.shape}")
print(f"Filtered dataset shape: {retail_filtered1.shape}")
# Out:
# Original dataset shape: (8827, 13)
# Filtered dataset shape: (8705, 13)

# %%
lower_bound= -0.30000000000000004
upper_bound= 0.5

# Apply this function to 'Discount' column
retail_filtered2 = remove_outliers(retail_filtered1, 'Discount', lower_bound, upper_bound)

# Check the shape of the dataset after removing outliers
print(f"Original dataset shape: {retail_filtered1.shape}")
print(f"Filtered dataset shape: {retail_filtered2.shape}")
# Out:
# Original dataset shape: (8705, 13)
# Filtered dataset shape: (7888, 13)

# %%
lower_bound= -39.724125
upper_bound= 70.816875

# Apply this function to 'Profit' column
retail_filtered3 = remove_outliers(retail_filtered2, 'Profit', lower_bound, upper_bound)

# Check the shape of the dataset after removing outliers
print(f"Original dataset shape: {retail_filtered2.shape}")
print(f"Filtered dataset shape: {retail_filtered3.shape}")
# Out:
# Original dataset shape: (7888, 13)
# Filtered dataset shape: (7143, 13)

# %% [markdown]
# ## Visualisation after removing outliers

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x=retail_filtered3['Sales'],color='green')
plt.title('Sales after removal of outliers')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x=retail_filtered3['Discount'],color='green')
plt.title('Discount after removal of outliers')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x=retail_filtered3['Profit'],color='green')
plt.title('Profit after removal of outliers')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x=retail_filtered3['Quantity'],color='green')
plt.title('Quantity after removal of outliers')
plt.show()

# %% [markdown]
# ## Checking normality of Data

# %%
import scipy.stats as stats

# %%
# Normal test for sales
statistic, p_value = stats.normaltest(retail_filtered3['Sales'])

print(f"Test Statistic: {statistic}")
print(f"P-value: {p_value}")

# Interpretation
if p_value > 0.05:
    print("Fail to reject the null hypothesis: The data is normally distributed for Sales.")
else:
    print("Reject the null hypothesis: The data is not normally distributed for Sales.")

#Visual representation Q-Q plot
stats.probplot(retail_filtered3.Sales,dist='norm',plot=plt)
plt.show()
# Out:
# Test Statistic: 2920.1462168091507
# P-value: 0.0
# Reject the null hypothesis: The data is not normally distributed for Sales.

# %%
# Normal test for Discount
statistic, p_value = stats.normaltest(retail_filtered3['Discount'])

print(f"Test Statistic: {statistic}")
print(f"P-value: {p_value}")

# Interpretation
if p_value > 0.05:
    print("Fail to reject the null hypothesis: The data is normally distributed.")
else:
    print("Reject the null hypothesis: The data is not normally distributed.")

#Visual representation Q-Q plot
stats.probplot(retail_filtered3.Discount,dist='norm',plot=plt)
plt.show()
# Out:
# Test Statistic: 6634.322380331369
# P-value: 0.0
# Reject the null hypothesis: The data is not normally distributed.

# %%
# Normal test for Quantity
statistic, p_value = stats.normaltest(retail_filtered3['Quantity'])

print(f"Test Statistic: {statistic}")
print(f"P-value: {p_value}")

# Interpretation
if p_value > 0.05:
    print("Fail to reject the null hypothesis: The data is normally distributed.")
else:
    print("Reject the null hypothesis: The data is not normally distributed.")

#Visual representation Q-Q plot
stats.probplot(retail_filtered3.Quantity,dist='norm',plot=plt)
plt.show()
# Out:
# Test Statistic: 876.5661450476508
# P-value: 4.5298110963357424e-191
# Reject the null hypothesis: The data is not normally distributed.

# %%
# Normal test for Profit
statistic, p_value = stats.normaltest(retail_filtered3['Profit'])

print(f"Test Statistic: {statistic}")
print(f"P-value: {p_value}")

# Interpretation
if p_value > 0.05:
    print("Fail to reject the null hypothesis: The data is normally distributed.")
else:
    print("Reject the null hypothesis: The data is not normally distributed.")

#Visual representation Q-Q plot
stats.probplot(retail_filtered3.Profit,dist='norm',plot=plt)
plt.show()
# Out:
# Test Statistic: 988.4641948788234
# P-value: 2.2789106741681637e-215
# Reject the null hypothesis: The data is not normally distributed.

# %% [raw]
# Hence, all the numerical variables are not normally distributed and we can not perform Parametric tests, we have to do Non-Parametric tests.

# %% [markdown]
# ## 8.	Bivariate analysis: Perform at least one analysis for each of the following hypothesis tests:
# -	Chi-square test to assess independence between two categorical variables.
# -	Correlation analysis to examine relationships between two numeric variables.
# -	T-test or Mann-Whitney U test to compare means between two groups.
# -	Analysis of Variance (ANOVA) to compare means across multiple groups.

# %% [markdown]
# ## Correlation Analysis

# %%
retail_filtered3.corr(numeric_only=True)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.127873  0.137533  0.396367
# Quantity  0.127873  1.000000 -0.027562  0.229934
# Discount  0.137533 -0.027562  1.000000 -0.310667
# Profit    0.396367  0.229934 -0.310667  1.000000

# %% [raw]
# Prediction of correlation through:
# •	R (coefficient of correlation):
# 0.5 ≤ |r| → High linear correlation
# 0.3 ≤ |r| < 0.5 → Medium linear correlation
# 0 ≤ |r| < 0.3 → Low linear correlation
# r=0➔no linear correlation
# r= +1 or -1➔perfect linear relationship
#
# •	P-value: P-value is more than 5% than we fail to reject null hypothesis (R=0) otherwise we accept alternative hypothesis.

# %%
sns.pairplot(retail_filtered3[['Sales','Quantity','Discount','Profit']])

# %%
sns.heatmap(retail_filtered3[['Sales','Discount','Quantity','Profit']].corr(),annot=True, cmap='Greens')
# Out:
# <Axes: >

# %% [raw]
# Let's check Correlation between following:
#
# Sales and Profit
# Sales and Discount
# Profit and Quantity
# Profit and Discount

# %% [markdown]
# ## Sales and Profit

# %% [raw]
# Hypothesis: (Will check the correlation by spearman as data is not normal.)
#
# Null Hypothesis (H₀): There is no relationship between Sales and Profit (correlation = 0).
# Alternative Hypothesis (H₁): There is a relationship between Sales and Profit (correlation ≠ 0).

# %%
import scipy.stats as stats

# %%
# Compute the Spearman correlation and p-value
corr, p_value = stats.spearmanr(retail_filtered3['Sales'], retail_filtered3['Profit'])

# Output the result
print(f"Spearman correlation coefficient: {corr}")
print(f"P-value: {p_value}")

# Interpretation
if p_value < 0.05:
    print("Reject the null hypothesis: There is a significant correlation between Sales and Profit.")
else:
    print("Fail to reject the null hypothesis: There is no significant correlation between Sales and Profit.")
# Out:
# Spearman correlation coefficient: 0.579338712798083
# P-value: 0.0
# Reject the null hypothesis: There is a significant correlation between Sales and Profit.

# %%
plt.scatter(retail_filtered3['Sales'],retail_filtered3['Profit'])
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ## Sales and Discount

# %% [raw]
# Hypothesis: (Will check the correlation by spearman as data is not normal.)
#
# Null Hypothesis (H₀): There is no relationship between Sales and Discount (correlation = 0).
# Alternative Hypothesis (H₁): There is a relationship between Sales and Discount (correlation ≠ 0).

# %%
import scipy.stats as stats

# %%
# Compute the Spearman correlation and p-value
corr, p_value = stats.spearmanr(retail_filtered3['Sales'], retail_filtered3['Discount'])

# Output the result
print(f"Spearman correlation coefficient: {corr}")
print(f"P-value: {p_value}")

# Interpretation
if p_value < 0.05:
    print("Reject the null hypothesis: There is a significant correlation between Sales and Discount.")
else:
    print("Fail to reject the null hypothesis: There is no significant correlation between Sales and Discount.")
# Out:
# Spearman correlation coefficient: 0.07703515525512244
# P-value: 7.064872797557394e-11
# Reject the null hypothesis: There is a significant correlation between Sales and Discount.

# %%
plt.scatter(retail_filtered3['Sales'],retail_filtered3['Discount'])
plt.xlabel('Sales')
plt.ylabel('Discount')
plt.show()

# %% [markdown]
# ## Chi-Square Analysis

# %%
import numpy as np
from scipy.stats import chi2_contingency
def chi_square(c1,c2):
    """ function to check significant difference between two categorical variables"""
    chi_2, p_val, dof, exp_val = chi2_contingency(pd.crosstab(retail_filtered3[c1],retail_filtered3[c2],margins = False))# make sure margins = False
    print("Actual values:\n")
    print(pd.crosstab(retail_filtered3[c1],retail_filtered3[c2],margins = False))
    print("="*100)
    print("Expected values: \n")
    print(exp_val)
    print("="*100)
    print(f'\nChi-square is : {chi_2}', f'\n\np_value is : {p_val}', f'\n\ndegree of freedom is :{dof}')
    print("="*100)
    if exp_val.min()<5 or np.sum(exp_val)<30 : print("\n********************************************\nWarning :We have some small expected \
values or the total number of observations is not enough to get any conclusion\n******************************************** ")
        #Note for sum of all values in dataframe use df.values.sum() and for numpy.ndarray use np.sum(arr)
    elif p_val < 0.05:# consider significan level is 5%
        print(F"\nThere is statistiacally significant correlation between {c1} and {c2} at 0.05 significant level")
    else:
        print(F"\nThere is no correlation between the two variables( we don't have enough evidence to conclude there is a a statistically significant relationship between {c1} and {c2}")

# %%
chi_square('Segment','Ship Mode')
# Out:
# Actual values:
#
# Ship Mode    First Class  Same Day  Second Class  Standard Class
# Segment
# Consumer             557       230           748            2198
# Corporate            344        72           448            1277
# Home Office          198        84           210             777
# ...
# Expected values:
#
# [[ 574.34789304  201.72728545  734.78902422 2222.13579728]
#  [ 329.40767185  115.69732605  421.42601148 1274.46899062]
#  [ 195.24443511   68.57538849  249.7849643   755.3952121 ]]
# ...
#
# Chi-square is : 34.280266484740345
#
# p_value is : 5.9388649255203134e-06
#
# degree of freedom is :6
# ...
#
# There is statistiacally significant correlation between Segment and Ship Mode at 0.05 significant level

# %%
chi_square('Segment','State')
# Out:
# Actual values:
#
# State        Alabama  Arizona  Arkansas  California  Colorado  Connecticut  \
# Segment
# Consumer          16       70        26         851        63           33
# Corporate         21       47        10         494        36           20
# Home Office        7       33         9         261        18            9
#
# State        Delaware  District of Columbia  Florida  Georgia  ...  \
# Segment                                                        ...
# Consumer           38                     5      124       61  ...
# Corporate          28                     0       92       45  ...
# Home Office         8                     3       43       30  ...
#
# State        South Carolina  South Dakota  Tennessee  Texas  Utah  Vermont  \
# Segment
# Consumer                 18             2         78    302    24        3
# Corporate                15             8         38    183    10        3
# ...

# %% [markdown]
# ## Categorical * Continuous

# %%
for cols in retail_filtered3.columns:
    if retail_filtered3[cols].dtype=='object':
        print(retail_filtered3[cols].value_counts())
# Out:
# Ship Mode
# Standard Class    4252
# Second Class      1406
# First Class       1099
# Same Day           386
# Name: count, dtype: int64
# Segment
# Consumer       3733
# Corporate      2141
# Home Office    1269
# Name: count, dtype: int64
# Country
# United States    7143
# Name: count, dtype: int64
# City
# New York City     709
# Los Angeles       600
# San Francisco     411
# Seattle           342
# Philadelphia      340
#                  ...
# Port Orange         1
# Portage             1
# Citrus Heights      1
# Moorhead            1
# Mason               1
# Name: count, Length: 508, dtype: int64
# State
# California              1606
# New York                 870
# Texas                    567
# Washington               403
# Pennsylvania             370
# Ohio                     306
# Florida                  259
# Illinois                 248
# Michigan                 188
# North Carolina           171
# Virginia                 167
# Arizona                  150
# ...

# %% [raw]
# Every Categorical variable have more than two levels so, we will do ANOVA analysis

# %% [raw]
# Profit*Category

# %%
import pingouin as pg
aov = pg.anova(data=retail, dv='Profit', between='Category', detailed=True)
print(aov)
# Out:
#      Source            SS    DF            MS          F         p-unc  \
# 0  Category  5.898009e+06     2  2.949004e+06  54.311023  3.469918e-24
# 1    Within  5.424958e+08  9991  5.429845e+04        NaN           NaN
#
#         np2
# 0  0.010755
# 1       NaN

# %% [raw]
# Source:
#
# Category: The between-group factor (your independent variable, in this case, 'Category').
# Within: The error or residual variance within each group.
# SS (Sum of Squares):
#
# For Category, the sum of squares is 5.898009e+06, which reflects the variance due to the differences between categories.
# For Within, the sum of squares is 5.424958e+08, which reflects the variance within the groups.
# DF (Degrees of Freedom):
#
# Category: The degrees of freedom for the between-group factor is 2 (since you have 3 categories).
# Within: The degrees of freedom for the within-group variance is 9991 (typically the total number of observations minus the number of groups).
# MS (Mean Square):
#
# Category: The mean square for the between-group factor is 2.949004e+06, which is the sum of squares for Category divided by its degrees of freedom.
# Within: The mean square for within-group variance is 5.429845e+04.
# F-statistic:
#
# The F-statistic is 54.311023, which tests the null hypothesis that there is no significant difference between the groups (the categories). The higher the F-statistic, the stronger the evidence against the null hypothesis.
# p-unc (Uncorrected p-value):
#
# The p-value for the between-group factor (Category) is 3.469918e-24, which is extremely small and indicates that the difference between categories is highly significant.
# np² (Eta squared):
#
# np2 = 0.010755: This is the effect size, which measures the proportion of variance explained by the between-group factor. A value of 0.010755 suggests a small effect size (since it is less than 0.01), meaning that the 'Category' variable explains a small portion of the variance in 'Profit'.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a grouped box plot
sns.boxplot(x='Category', y='Profit', data=retail, color='green')

# Set plot labels and title
plt.title('Grouped Box Plot of Profit by Category')
plt.xlabel('Category')
plt.ylabel('Profit')

# Show the plot
plt.show()

# %% [raw]
# Sales * Region

# %%
import pingouin as pg
aov = pg.anova(data=retail, dv='Sales', between='Region', detailed=True)
print(aov)
# Out:
#    Source            SS    DF             MS         F    p-unc      np2
# 0  Region  9.330200e+05     3  311006.661044  0.800619  0.49332  0.00024
# 1  Within  3.880692e+09  9990  388457.706898       NaN      NaN      NaN

# %% [raw]
# Source:
#
# Region: The factor you're testing, which likely refers to different regions in your data.
# Within: The residual or error variance within each region.
# SS (Sum of Squares):
#
# Region: The sum of squares for the between-group factor is 9.330200e+05, which shows the variability due to the differences between regions.
# Within: The sum of squares for within-group variability is 3.880692e+09, representing the variability within regions.
# DF (Degrees of Freedom):
#
# Region: The degrees of freedom for the Region factor is 3. This suggests that there are four groups (because the degrees of freedom are typically one less than the number of groups).
# Within: The degrees of freedom for within-group variance is 9990, indicating the number of observations minus the number of groups.
# MS (Mean Square):
#
# Region: The mean square for the between-group factor is 311006.661044, calculated as SS / DF for the Region.
# Within: The mean square for within-group variability is 388457.706898, calculated as SS / DF for the Within group.
# F-statistic:
#
# The F-statistic is 0.800619. The F-statistic is used to compare the variances between the groups (Region) relative to the variance within the groups. Since this value is relatively low, it suggests that the between-group variability is not much larger than the within-group variability.
# p-unc (Uncorrected p-value):
#
# The p-value is 0.49332, which is much larger than the commonly used significance threshold of 0.05. This indicates that there is no significant difference between the regions in terms of the dependent variable (the variable you're measuring, like 'Profit').
# np² (Eta squared):
#
# The effect size (np2) is 0.00024. This value is very small, indicating that the Region factor explains only a very tiny proportion of the variance in your dependent variable.

# %%
sns.boxplot(x='Sales', y='Region', data=retail, color='green')

# Set plot labels and title
plt.title('Grouped Box Plot of Sales by Region')
plt.xlabel('Category')
plt.ylabel('Profit')

# Show the plot
plt.show()

# %% [markdown]
# ## Collinearity and Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
num_cols = retail.select_dtypes(include=[np.number]).columns

# Check for multicollinearity using Variance Inflation Factor (VIF)
def calculate_vif(df, features):
    vif_data = pd.DataFrame()
    vif_data["Feature"] = features
    vif_data["VIF"] = [variance_inflation_factor(df[features].values, i) for i in range(len(features))]
    return vif_data

vif_df = calculate_vif(retail, num_cols)
print("\nVariance Inflation Factor (VIF):")
print(vif_df)
# Out:
# Variance Inflation Factor (VIF):
#     Feature       VIF
# 0     Sales  1.542570
# 1  Quantity  1.578770
# 2  Discount  1.449113
# 3    Profit  1.386036

# %% [raw]
# The VIF values indicate that none of the features exhibit strong multicollinearity (generally, a VIF above 5 or 10 is concerning)

# %% [markdown]
# ## Training and Test dataset

# %%
from sklearn.model_selection import train_test_split, cross_val_score

y = retail['Category']  # Target variable
X = retail.drop(columns=['Category'])  # All predictors

# Data preprocessing
# Encoding categorical variables using one-hot encoding
X_encoded = pd.get_dummies(X, drop_first=True)
X_encoded= X_encoded.astype(int)

# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.4, random_state=42)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, r2_score, mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Scaling data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Classification models
log_reg = LogisticRegression()
dt_clf = DecisionTreeClassifier()
log_reg.fit(X_train_scaled, y_train)
dt_clf.fit(X_train_scaled, y_train)

# Classification evaluation
log_pred = log_reg.predict(X_test_scaled)
dt_pred = dt_clf.predict(X_test_scaled)
print("\nLogistic Regression Accuracy:", accuracy_score(y_test, log_pred))
print("\nDecision Tree Accuracy:", accuracy_score(y_test, dt_pred))
# Out:
# Logistic Regression Accuracy: 0.9997498749374687
#
# Decision Tree Accuracy: 0.9992496248124062

# %% [raw]
# Logistic Regression and Decision Tree models are both achieving near-perfect accuracy (≈99.97% and 99.92%, respectively). This suggests potential overfitting, especially for the Decision Tree.

# %%
import statsmodels.api as sm

# Classification models with improvements
log_reg = LogisticRegression(penalty='l2', C=0.1, solver='liblinear')
dt_clf = DecisionTreeClassifier(max_depth=5, min_samples_leaf=10, ccp_alpha=0.01)
log_reg.fit(X_train_scaled, y_train)
dt_clf.fit(X_train_scaled, y_train)

# Cross-validation to check model robustness
log_cv_scores = cross_val_score(log_reg, X_train_scaled, y_train, cv=5, scoring='accuracy')
dt_cv_scores = cross_val_score(dt_clf, X_train_scaled, y_train, cv=5, scoring='accuracy')

print("\nLogistic Regression Cross-validation Accuracy:", log_cv_scores.mean())
print("\nDecision Tree Cross-validation Accuracy:", dt_cv_scores.mean())

# Check for overfitting in Decision Tree
print("\nDecision Tree Train Accuracy:", dt_clf.score(X_train_scaled, y_train))
print("Decision Tree Test Accuracy:", dt_clf.score(X_test_scaled, y_test))
# Out:
# Logistic Regression Cross-validation Accuracy: 0.9968306922435364
#
# Decision Tree Cross-validation Accuracy: 0.9067720322490965
#
# Decision Tree Train Accuracy: 0.9067711807871914
# Decision Tree Test Accuracy: 0.900200100050025

# %% [raw]
# Decision Tree model is no longer overfitting, as its training and test accuracies are similar. However, the Logistic Regression model still has an extremely high accuracy. This may indicate class imbalance or redundant features.

# %%
y = retail['Sales']  # Target variable
X = retail[['Profit','Quantity','Discount']]  # All predictors

# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
# Scaling data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Regression models
lin_reg = LinearRegression()
dt_reg = DecisionTreeRegressor()
lin_reg.fit(X_train_scaled, y_train)
dt_reg.fit(X_train_scaled, y_train)

# Regression evaluation
lin_pred = lin_reg.predict(X_test_scaled)
dt_pred_reg = dt_reg.predict(X_test_scaled)
print("\nLinear Regression R2:", r2_score(y_test, lin_pred))
print("\nDecision Tree Regression R2:", r2_score(y_test, dt_pred_reg))
# Out:
# Linear Regression R2: 0.04130628464726105
#
# Decision Tree Regression R2: 0.49126722632018593

# %% [raw]
# Linear Regression R² score is quite low (0.041), indicating that the model is not explaining much variance in the target variable. On the other hand, the Decision Tree Regression has a much higher R² score (0.491), suggesting it performs significantly better.

# %%
# Visualization for regression models
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=lin_pred, label="Linear Regression")
sns.scatterplot(x=y_test, y=dt_pred_reg, label="Decision Tree Regression")
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Regression Model Predictions vs Actual Values")
plt.legend()
plt.show()
